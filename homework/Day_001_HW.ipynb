# %% [markdown]
# 作業1：
# 我選擇的資料是：Google Play Store Apps
# 1. 你選的這組資料為何重要？
#     - 對於開發行動應用程式的開發者或是公司，可以了解使用者的喜好，以及使用者對不同類型應用程式的接受度。
# 2. 資料從何而來？
#     - ksggle上的使用者到Google Play Store抓取資料。
# 3. 搜集而來的資料型態為何？
#     - 結構化的資料，資料型態為數字或文字。
# 4. 這組資料想解決的問題如何評估？
#     - 用正確率來評估推薦給使用者的應用程式是否符合使用者喜好或需求。

# %% [markdown]
# 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     - 假設這個車隊有一個自己專屬的叫車APP，顧客可以透過APP叫車，也可在路邊攔車搭乘。
#     - 假設提升業績可以透過「提升原有客戶再搭乘率」、「增加新客戶」來達成。
#     - 「提升原有客戶再搭乘率」：如果為經常性叫車提供優惠卷，如果是原本再搭乘率不高之客戶則發送問卷調查了解原因，填寫完畢後贈送優惠卷。
#     - 「增加新客戶」：分析人潮較多之地點以及司機停車地點，將人潮較多之地點即時發送給司機。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     - 資料可以透過APP蒐集，蒐集顧客叫車與乘車紀錄、司機行駛的路線、司機停車等待新顧客上門的地點。
# 3. 蒐集而來的資料型態為何
#     - 乘車紀錄應為結構化的資料，司機行駛路線、等待地點應為地圖型態之非結構化資料。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     - 分析原有顧客在發送優惠卷後的搭乘率是否有提升。
#     - 分析司機載到的新客戶數是否有增加。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_h):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y-y_h)**2)/len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 217.641
# The Mean absolute error is 11.583
